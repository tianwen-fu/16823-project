# %%
import matplotlib.pyplot as plt
from capture_frames import DepthData
import numpy as np
import pickle

# %%
with open("out.pkl", "rb") as f:
    frames: list[DepthData] = pickle.load(f)

# %%
len(frames)
# Out:
# 4

# %%
plt.imshow(frames[0].grayscale)

# %%
plt.hist(frames[0].grayscale.flatten(), bins=100)
# Out:
# (array([7.595e+03, 5.873e+03, 1.880e+02, 5.250e+02, 7.140e+02, 6.210e+02,
#         4.840e+02, 4.580e+02, 3.870e+02, 3.260e+02, 3.410e+02, 3.170e+02,
#         3.310e+02, 3.950e+02, 4.490e+02, 5.140e+02, 6.670e+02, 7.980e+02,
#         7.020e+02, 7.720e+02, 7.930e+02, 7.670e+02, 8.270e+02, 8.190e+02,
#         6.350e+02, 6.640e+02, 6.020e+02, 5.500e+02, 5.160e+02, 5.420e+02,
#         5.760e+02, 4.440e+02, 4.860e+02, 4.500e+02, 3.750e+02, 4.460e+02,
#         3.760e+02, 3.170e+02, 3.350e+02, 3.490e+02, 2.940e+02, 2.760e+02,
#         2.490e+02, 2.580e+02, 2.430e+02, 2.220e+02, 2.340e+02, 2.100e+02,
#         2.030e+02, 1.810e+02, 2.090e+02, 1.780e+02, 1.340e+02, 1.550e+02,
#         1.550e+02, 1.350e+02, 1.300e+02, 1.180e+02, 1.160e+02, 1.260e+02,
#         1.290e+02, 1.120e+02, 1.160e+02, 1.120e+02, 1.040e+02, 1.000e+02,
#         9.200e+01, 6.400e+01, 7.000e+01, 6.900e+01, 4.500e+01, 3.400e+01,
#         2.300e+01, 1.000e+01, 9.000e+00, 5.000e+00, 5.000e+00, 5.000e+00,
# ...
